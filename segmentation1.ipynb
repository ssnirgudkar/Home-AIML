# %% [markdown]
# <a href="https://colab.research.google.com/github/ssnirgudkar/Home-AIML/blob/main/segmentation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### This code reads a labeled image from segments.io. It's an objected segmentation. We convert that to semantic and also squash the number of classes
##### It reads the labeled image and creates the output image in the google drive. The release file is downloaded and converted to a png file separately. 
##### The program loops through all the files
pip install --upgrade segments-ai
# Out:
# Requirement already up-to-date: segments-ai in /usr/local/lib/python3.7/dist-packages (0.29)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from segments-ai) (4.41.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from segments-ai) (2.23.0)
# Requirement already satisfied, skipping upgrade: pycocotools in /usr/local/lib/python3.7/dist-packages (from segments-ai) (2.0.2)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from segments-ai) (1.19.5)
# Requirement already satisfied, skipping upgrade: Pillow in /usr/local/lib/python3.7/dist-packages (from segments-ai) (7.0.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->segments-ai) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->segments-ai) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->segments-ai) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->segments-ai) (2020.12.5)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools->segments-ai) (0.29.22)
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools->segments-ai) (54.0.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools->segments-ai) (3.2.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->segments-ai) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->segments-ai) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->segments-ai) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->segments-ai) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools->segments-ai) (1.15.0)

# %%
pip install --upgrade segments-ai

# %%
from segments import SegmentsClient
api_key = "a89182567b17766b91773021b18d04574cd75109"
client = SegmentsClient(api_key)
# Out:
# Initialized successfully.

# %%
user = "ssnirgudkar"
datasets = client.get_datasets(user)
for dataset in datasets:
    print(dataset["name"],dataset["description"])
# Out:
# playground This dataset contains some images for trying out the Segments.ai labeling tool.
# Test
# PilotIR Data set of 103 IR images for segmentation purpose
# ReferenceColorImagesForIRImages

# %%
dataset_identifier = "ssnirgudkar/PilotIR"
dataset = client.get_dataset(dataset_identifier)
print(dataset)
# Out:
# {'name': 'PilotIR', 'description': 'Data set of 103 IR images for segmentation purpose', 'data_type': 'IMAGE', 'category': 'other', 'public': False, 'owner': {'username': 'ssnirgudkar', 'created_at': '2020-10-22T02:36:24Z'}, 'created_at': '2020-11-14T17:25:35.948618Z', 'task_type': 'segmentation-bitmap', 'task_attributes': {'format_version': '0.1', 'categories': [{'name': 'object', 'id': 0}, {'name': 'sky', 'id': 1}, {'name': 'water', 'id': 2}, {'name': 'warm entity', 'id': 3}, {'name': 'background', 'id': 4}, {'name': 'cold entity', 'id': 5}, {'name': 'sun', 'id': 6}]}, 'task_readme': '', 'collaborators_count': 5, 'samples_count': 103, 'role': 'admin', 'readme': '# PilotIR\nData set of 103 IR images for segmentation purpose', 'noncollaborator_can_label': False, 'noncollaborator_can_review': False, 'tasks': [{'uuid': '30d45088-6023-4f2e-bcb3-ef38994446ba', 'name': 'segmentation', 'description': '', 'readme': '', 'task_type': 'segmentation-bitmap', 'attributes': {'format_version': '0.1', 'categories': [{'name': 'object', 'id': 0}, {'name': 'sky', 'id': 1}, {'name': 'water', 'id': 2}, {'name': 'warm entity', 'id': 3}, {'name': 'background', 'id': 4}, {'name': 'cold entity', 'id': 5}, {'name': 'sun', 'id': 6}]}, 'is_groundtruth': True, 'statistics': {'prelabeled_count': 0, 'labeled_count': 103, 'reviewed_count': 0, 'rejected_count': 0, 'skipped_count': 0, 'samples_count': 103}, 'stats': {}, 'created_at': '2020-11-14T17:26:41.875726Z'}], 'labelsets': [{'name': 'segmentation', 'description': '', 'is_groundtruth': True, 'created_at': '2020-11-14T17:26:41.875726Z'}]}

# %%
from segments import SegmentsDataset
from segments.utils import export_dataset

# Initialize a SegmentsDataset from the release file
release_file = client.get_release(dataset_identifier,'V2.0')
#print(release_file)
releasedataset = SegmentsDataset(release_file, labelset='segmentation', filter_by='labeled')

# Export to COCO panoptic format
#export_dataset(releasedataset, export_format='coco-panoptic')
# Out:
#  22%|██▏       | 23/103 [00:00<00:00, 228.55it/s]
# Initializing dataset. This may take a few seconds...
# 100%|██████████| 103/103 [00:00<00:00, 291.62it/s]
# Initialized dataset with 103 images.

# %%
import matplotlib.pyplot as plt 
from segments.utils import get_semantic_bitmap
for sample in releasedataset:
  print(sample['name'])
  print (sample['annotations'])
# Out:
# 1602782502.365406.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1602782484.167264.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 1}]
# 1602782428.150594.png
# [{'id': 3, 'category_id': 2}, {'id': 5, 'category_id': 5}, {'id': 11, 'category_id': 4}, {'id': 12, 'category_id': 1}]
# 1602782432.900543.png
# [{'id': 2, 'category_id': 1}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 4}, {'id': 8, 'category_id': 5}]
# 1602782433.588707.png
# [{'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 4}, {'id': 6, 'category_id': 1}, {'id': 7, 'category_id': 5}]
# 1602782591.765597.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}]
# 1602782542.023886.png
# [{'id': 1, 'category_id': 3}, {'id': 2, 'category_id': 5}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 2}]
# 1602782608.155838.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782672.387383.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782688.896356.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782761.761287.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 3}]
# 1602782781.360750.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 4, 'category_id': 3}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 1}]
# 1602782702.449059.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}]
# 1602782790.295318.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782782.927524.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}]
# 1602783091.137741.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 3}]
# 1602783073.004248.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602783115.353168.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 3}]
# 1603135779.108368.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 6}]
# 1603135903.339080.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 6}]
# 1603135914.538867.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 5}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 6}]
# 1603135915.838872.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 3}, {'id': 5, 'category_id': 2}]
# 1603211572.045710.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1603211572.645065.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 3}, {'id': 4, 'category_id': 5}, {'id': 5, 'category_id': 2}]
# 1603211573.145489.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1603211820.346932.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603212627.448519.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 3}]
# 1603212649.349174.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 3}]
# 1603212655.481819.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}]
# 1603212690.849901.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 5}]
# 1603212921.652774.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 5}]
# 1603212955.383357.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603212940.117117.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}]
# 1603212986.516563.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1603213022.483051.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}]
# 1603213005.216054.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1603213054.484426.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603213119.352306.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 3}]
# 1603391645.422605.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 5}, {'id': 5, 'category_id': 6}]
# 1603213227.383862.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}]
# 1603391605.223658.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391669.105418.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391813.269268.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391700.621438.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 4}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 6}]
# 1603391817.769427.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391810.835577.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391823.402759.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 5}, {'id': 5, 'category_id': 2}]
# 1603392003.431485.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 3}, {'id': 5, 'category_id': 2}]
# 1603392043.830625.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 6}]
# 1603392142.161714.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603392383.356605.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 6}]
# 1602782427.667751.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 5}]
# 1602782428.750998.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 5}, {'id': 7, 'category_id': 3}]
# 1602782438.213536.png
# [{'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782432.750959.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 5}, {'id': 7, 'category_id': 3}]
# 1602782434.610408.png
# [{'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 3}, {'id': 5, 'category_id': 4}, {'id': 6, 'category_id': 2}, {'id': 7, 'category_id': 1}]
# 1602782448.917012.png
# [{'id': 1, 'category_id': 3}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}]
# 1602782532.698585.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782475.409516.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}]
# 1602782447.750546.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 3}]
# 1602782493.466760.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}]
# 1602782542.674922.png
# [{'id': 1, 'category_id': 5}, {'id': 5, 'category_id': 4}, {'id': 6, 'category_id': 2}, {'id': 7, 'category_id': 1}]
# 1602782551.308124.png
# [{'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 5}, {'id': 5, 'category_id': 2}, {'id': 6, 'category_id': 4}, {'id': 7, 'category_id': 1}]
# 1602782540.691839.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}]
# 1602782552.308129.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782559.591311.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 3}]
# 1602782570.991061.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782561.075007.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}, {'id': 6, 'category_id': 3}]
# 1602782580.794397.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782595.493716.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 2}]
# 1602782576.224337.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782648.457371.png
# [{'id': 1, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782642.829391.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1602782661.642178.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782664.672424.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782651.939140.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782701.124706.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 1}]
# 1602782732.688501.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782669.661998.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602782816.589612.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1602782821.519517.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 1}]
# 1602783046.314322.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1602783075.829511.png
# [{'id': 1, 'category_id': 2}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 3}]
# 1602782826.487520.png
# [{'id': 1, 'category_id': 4}, {'id': 5, 'category_id': 2}, {'id': 8, 'category_id': 5}, {'id': 9, 'category_id': 1}]
# 1602783100.546920.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 3}]
# 1602783126.245902.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 3}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 1}]
# 1603391676.348541.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391605.417474.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391725.231131.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}]
# 1603391774.363513.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391807.662584.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391813.562806.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391862.128166.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391977.127352.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391973.126007.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603391920.193870.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 3}, {'id': 5, 'category_id': 2}]
# 1603392007.225150.png
# [{'id': 1, 'category_id': 1}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603392008.958178.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 4}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 1}, {'id': 5, 'category_id': 3}, {'id': 6, 'category_id': 6}]
# 1603392077.957221.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 2}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 4}, {'id': 5, 'category_id': 6}]
# 1603392079.023728.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 1}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603391979.492541.png
# [{'id': 1, 'category_id': 5}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 4}, {'id': 4, 'category_id': 2}, {'id': 5, 'category_id': 6}]
# 1603392376.184610.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 1}, {'id': 3, 'category_id': 5}, {'id': 4, 'category_id': 2}]
# 1603392210.587620.png
# [{'id': 1, 'category_id': 4}, {'id': 2, 'category_id': 5}, {'id': 3, 'category_id': 2}, {'id': 4, 'category_id': 1}]

# %%
#plt.imshow(sample['image'])
#plt.show()

# %%
#plt.imshow(sample['segmentation_bitmap'])
#plt.show()

# %%
#semantic_bitmap=get_semantic_bitmap(sample['segmentation_bitmap'], sample['annotations'])
#plt.imshow(semantic_bitmap)
#plt.show()

# %%
 import cv2 
 import numpy as np
 import os 
 
 #arr1 = [4,5,2,1]
 #infilename = '/content/drive/MyDrive/Image-masked-input/1603392210.587620_label_segmentation.png'
 #infilename = '/content/segments/ssnirgudkar_PilotIR/V2.0/1603392210.587620_label_segmentation.png'
 #filename = infilename[43:60:1]+'.png'

 #infilename = '/content/1602782427.667751_label_segmentation.png'
 #filename = infilename[9:26:1]+'.png'
 #read all files from input directory - /content/segments/ssnirgudkar_PilotIR/V2.0/ that end with label_segmentation.png
 for filesindir in os.listdir("/content/segments/ssnirgudkar_PilotIR/V2.0/"):
   if filesindir.endswith("_label_segmentation.png"):
      
      filetext = filesindir.rstrip('_label_segmentation.png')
      filename = filetext+'.png'
      #print(filename)
      #filename = '1602782427.667751.png'
      for sample in releasedataset:
        if sample['name'] == filename:
          #print('in the loop')
          #print(sample['name'])
          #get filename for reading inout file and writing outputfile. remove .png from the filename 
          str = sample['name'].rstrip('.png')
          ##print(str) 
          labeledfile = str+'_label_segmentation.png'
          
     #t1=sample['name']
     #print(type(sample))  -- this is a dictionary 
     #print(type(t1)) -- this is a string 
     #print(t1[1])  -- this prints the 2nd digit in the image name 
     #print(sample['annotations'])  - this prints the values under annotations key for that image 
     #print(type(sample['annotations'])) -- this is a list 
     #print(l1[0])  -- this prints all the attributes for the 1st key 
     #print(type(l1[0])) -- this is dictionary 
     #print(l1[1]['id'],l1[1]['category_id']) - prints the id and category id for the 2nd key 
     #open the image, read each pixel, for all pixels in the image, run a for loop 
     #over and over on this 1 annotation to convert the pixel value 
          l1=sample['annotations']
          #print(l1)
     #print (l1[1]['id'], l1[1]['category_id'])
          
     #finding max of instance ids for an image 
          #print(len(l1)) 
          #id
          maxinstanceidinimage = len(l1)
          infilename = "/content/segments/ssnirgudkar_PilotIR/V2.0/"+labeledfile
          img = cv2.imread(infilename, cv2.IMREAD_UNCHANGED)
          assert not isinstance(img,type(None)), 'image not found'
          print ("file read = {0}".format(infilename))
          
          img2 = img.copy()
          #print(img[162,:])
          #print(img)
     #print(img.dtype)
          height,width = img.shape
     #print (img.shape)
     
          for i in range(height):
            for j in range(width):
              if img.item(i,j) == 0:
                img2.itemset((i,j), 0)
     
              else:
                  for m in range (0,maxinstanceidinimage,1):
                    #print (l1[m]['id'])
                    #if pixel value is found in category, replace with category 
                    if img.item(i,j) == l1[m]['id']:
                       img2.itemset((i,j), l1[m]['category_id']) 
                       #now collapse 6 categories into 3 - 7 - ob, 8 - sky, 9 - water

                       if img2.item(i,j) == 0:
                          img2.itemset((i,j), 7)  #object -> object 
                       if img2.item(i,j) == 1:
                          img2.itemset((i,j), 8)  #sky -> sky 
                       if img2.item(i,j) == 2:
                          img2.itemset((i,j), 9)  #water -> water
                       if img2.item(i,j) == 3:
                          img2.itemset((i,j), 7)  #warm entity -> object
                       if img2.item(i,j) == 4:
                          img2.itemset((i,j), 7)  #backgnd -> object
                       if img2.item(i,j) == 5:
                          img2.itemset((i,j), 7)  #cold entity -> object
                       if img2.item(i,j) == 6:
                          img2.itemset((i,j), 8)  #sun -> sky
                          
              
                         
                          
          #img.itemset((i,j), arr1[img.item(i,j)-1])  
          #print('out of the translation loop')   
       
          outputfilename = '/content/drive/MyDrive/image-masked-output/'+str+'_relabeled.png'
          cv2.imwrite(outputfilename, img2)  
          print ("file written = {0}".format(outputfilename))
          #print(img[5,:])
          #print(img2[162,:])
          #print(img)
          #print('new file written')
# Out:
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391920.193870_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391920.193870_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782664.672424_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782664.672424_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782782.927524_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782782.927524_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782826.487520_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782826.487520_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782428.150594_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782428.150594_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603213119.352306_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603213119.352306_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782702.449059_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782702.449059_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782669.661998_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782669.661998_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212627.448519_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212627.448519_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392210.587620_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392210.587620_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603213005.216054_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603213005.216054_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392079.023728_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392079.023728_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782642.829391_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782642.829391_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782781.360750_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782781.360750_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782570.991061_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782570.991061_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783075.829511_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783075.829511_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783073.004248_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783073.004248_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392008.958178_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392008.958178_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391862.128166_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391862.128166_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782790.295318_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782790.295318_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392077.957221_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392077.957221_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783126.245902_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783126.245902_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782732.688501_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782732.688501_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603135915.838872_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603135915.838872_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212655.481819_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212655.481819_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212986.516563_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212986.516563_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782559.591311_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782559.591311_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782428.750998_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782428.750998_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603135903.339080_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603135903.339080_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391823.402759_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391823.402759_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391977.127352_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391977.127352_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603135779.108368_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603135779.108368_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782816.589612_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782816.589612_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391774.363513_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391774.363513_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392383.356605_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392383.356605_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782608.155838_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782608.155838_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391817.769427_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391817.769427_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391645.422605_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391645.422605_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782561.075007_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782561.075007_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391979.492541_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391979.492541_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603211572.045710_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603211572.045710_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783091.137741_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783091.137741_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212690.849901_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212690.849901_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782432.750959_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782432.750959_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782448.917012_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782448.917012_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212955.383357_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212955.383357_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782542.674922_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782542.674922_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391605.223658_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391605.223658_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782551.308124_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782551.308124_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391700.621438_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391700.621438_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782648.457371_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782648.457371_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782595.493716_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782595.493716_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782447.750546_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782447.750546_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783115.353168_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783115.353168_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783046.314322_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783046.314322_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782540.691839_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782540.691839_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391676.348541_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391676.348541_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391807.662584_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391807.662584_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391605.417474_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391605.417474_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391813.269268_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391813.269268_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603213054.484426_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603213054.484426_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602783100.546920_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602783100.546920_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603211572.645065_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603211572.645065_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391669.105418_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391669.105418_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392142.161714_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392142.161714_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782493.466760_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782493.466760_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782432.900543_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782432.900543_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392007.225150_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392007.225150_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782688.896356_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782688.896356_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212649.349174_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212649.349174_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782661.642178_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782661.642178_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392043.830625_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392043.830625_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782542.023886_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782542.023886_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391813.562806_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391813.562806_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782580.794397_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782580.794397_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392376.184610_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392376.184610_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391973.126007_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391973.126007_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782761.761287_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782761.761287_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212940.117117_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212940.117117_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782475.409516_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782475.409516_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603213227.383862_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603213227.383862_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603211573.145489_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603211573.145489_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782484.167264_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782484.167264_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782576.224337_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782576.224337_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782532.698585_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782532.698585_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391810.835577_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391810.835577_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782433.588707_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782433.588707_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782651.939140_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782651.939140_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782591.765597_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782591.765597_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603213022.483051_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603213022.483051_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782701.124706_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782701.124706_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782552.308129_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782552.308129_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782672.387383_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782672.387383_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603212921.652774_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603212921.652774_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782821.519517_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782821.519517_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603392003.431485_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603392003.431485_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782434.610408_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782434.610408_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782427.667751_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782427.667751_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782438.213536_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782438.213536_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603391725.231131_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603391725.231131_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603135914.538867_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603135914.538867_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1603211820.346932_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1603211820.346932_relabeled.png
# file read = /content/segments/ssnirgudkar_PilotIR/V2.0/1602782502.365406_label_segmentation.png
# file written = /content/drive/MyDrive/image-masked-output/1602782502.365406_relabeled.png
